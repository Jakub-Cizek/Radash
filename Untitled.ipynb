# %%
import radash
import numpy as np
import matplotlib.pyplot as plt

# %%
a=radash.Material('alloy', ['V','Ti','Zr','Hf'],[1,2,3,4])
# Out:
# material: alloy
# number of constituents: 4
# V  23  0.100
# Ti 22  0.200
# Zr 40  0.300
# Hf 72  0.400

# %%
a.get_arc_dpa_spectrum(1e16,1,spectrum='neutron_energy_spectrum_LVR15.txt',plot=True)
# Out:
# V   6.120 g/cm3
# Ti  4.500 g/cm3
# Zr  6.510 g/cm3
# Hf 13.280 g/cm3
# composition weighted mean density: 8.777 g/cm3
# ----------------------------------------------------------------------------------------------------
# V   50.942 g/mol
# Ti  47.867 g/mol
# Zr  91.224 g/mol
# Hf 178.490 g/mol
# composition weighted molar weight: 113.431 g/mol
# ----------------------------------------------------------------------------------------------------
# determination of threshold atom displacement energy
# V  40.000 eV
# Ti 30.000 eV
# Zr 40.000 eV
# Hf 90.000 eV
# composition weighted threshold atom displacement energy: 58.000 eV
# ----------------------------------------------------------------------------------------------------
# arc dpa constants
# V  b = -0.680, c = 0.160
# Ti b = -0.568, c = 0.286
# Zr b = -0.880, c = 0.150
# Hf b = -0.560, c = 0.120
# composition weighted arc dpa constants: b = -0.670, c = 0.166
# ...
